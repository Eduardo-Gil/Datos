# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardo-Gil/Datos/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
# 1) Leer los datos del archivo CSV y guardarlos en un dataframe de Pandas.
url = "https://raw.githubusercontent.com/Eduardo-Gil/Datos/main/datos.csv"
df = pd.read_csv(url)

# %%
import pandas as pd
import numpy as np

# %%
#2) Graficar el total de registros reportados por sector usando un gráfico de torta.
import matplotlib.pyplot as plt

df_fil = df.groupby(by = 'Sector').sum()
plt.title("registros reportados por sector")
plt.pie(df_fil['Reportados'],labels=df_fil.index, autopct= "%0.1f %%")
plt.show()

# %%
#3) Graficar el total de registros válidos por sector usando un gráfico de torta.
import matplotlib.pyplot as plt
df_fil = df.groupby(by = 'Sector').sum()
plt.title("registros validos por sector")
plt.pie(df_fil['Validos'],labels=df_fil.index, autopct= "%0.1f %%")
plt.show()

# %%
#4) Graficar el total de registros rechazados por sector usando un gráfico de torta.
import matplotlib.pyplot as plt

df_fil = df.groupby(by = 'Sector').sum()
plt.title("registros rechazados por sector")
plt.pie(df_fil['Rechazados'],labels=df_fil.index, autopct= "%0.1f %%")
plt.show()

# %%
#5) Imprimir en salida estándar la entidad que tuvo más registros rechazados.
df_fil2 = df.groupby(by = 'Entidad').sum()
df_fil2 = df_fil2.sort_values(by="Rechazados", ascending=False).head(1)
print(df_fil2)
# Out:
#             Reportados   Validos  Rechazados
# Entidad
# Entidad 47   101898456  84853179    17045277
